# %%
import pandas as pd

# %%
data = pd. read_csv("test.csv")

# %%
data.head()
# Out:
#    id  is_free  price                     genres  \
# 0   0    False   3500           Action,Adventure
# 1   1    False  11600  Action,Adventure,Strategy
# 2   2    False   2100  Indie,Simulation,Strategy
# 3   3    False   3600            Action,Strategy
# 4   4    False   3400           Action,Adventure
#
#                                           categories  \
# 0              Single-player,Full controller support
# 1  Single-player,Multi-player,Online Multi-Player...
# 2  Single-player,Steam Achievements,Steam Trading...
# 3                   Single-player,Multi-player,Co-op
# 4  Single-player,Co-op,Steam Achievements,Full co...
#
#                                                 tags purchase_date  \
# 0  Action,Adventure,Horror,Third Person,Singlepla...  Oct 28, 2018
# 1  Mechs,Strategy,Turn-Based,Turn-Based Tactics,S...  Jul 20, 2019
# 2  Strategy,Simulation,Indie,Political,Cold War,P...  Jul 16, 2019
# 3                  Strategy,Action,Military,Tactical  Jan 30, 2018
# ...
